# %% [markdown]
# **Hi. This is part of a series of notbooks used for my Coursera IBM data Science Professional Certificate capstone project. This is week 03.**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Get data, set up a dataframe for clean-up

# %%
# !wget -q -O raw.html https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
df = pd.read_html('raw.html')
df = df[0]
x, y = df.shape

# %% [markdown]
# Drop 'Not assigned' Boroughs

# %%
droplist = []
for i in range(x):
  if df['Borough'].iloc[i] == 'Not assigned':
    droplist.append(i)
df = df.drop(droplist)
df = df.reset_index()
del df['index']

# %% [markdown]
# Rename unnamed neigbourhoods

# %%
x, y = df.shape
for i in range(x):
  if df['Neighbourhood'].iloc[i] == 'Not assigned':
    df['Neighbourhood'].iloc[i] = df['Borough'].iloc[i]

# %% [markdown]
# Now, we reduce the number of entries to the number of postalcodes by merging neighbourhoods.

# %%
droplist = []
for i in range(x):
  for j in range(x):
    if df['Postcode'].iloc[j] == df['Postcode'].iloc[i] and i > j:
      df['Neighbourhood'].iloc[i] = df['Neighbourhood'].iloc[i]+ ', ' + df['Neighbourhood'].iloc[j]
      droplist.append(j)
df = df.drop(droplist)
df = df.reset_index()
del df['index']

# %%
df.head()
# Out:
#   Postcode           Borough                     Neighbourhood
# 0      M3A        North York                         Parkwoods
# 1      M4A        North York                  Victoria Village
# 2      M5A  Downtown Toronto         Regent Park, Harbourfront
# 3      M6A        North York  Lawrence Manor, Lawrence Heights
# 4      M7A      Queen's Park                      Queen's Park

# %%
df.shape
# Out:
# (103, 3)

# %% [markdown]
# **Part 2**

# %%
# !wget -q -O codes.csv https://cocl.us/Geospatial_data
print('Data downloaded!')
# Out:
# Data downloaded!

# %%
df_codes = pd.read_csv('codes.csv')

# %% [markdown]
# Find the latitude and longitude for each entry from the CSV dataframe.

# %%
df['Latitude'] = 'n/a'
df['Longitude'] = 'n/a'
x1, y1 = df.shape
x2, y2 = df_codes.shape
for i in range(x1):
  for j in range(x2):
    if df['Postcode'].iloc[i] == df_codes['Postal Code'].iloc[j]:
      df['Latitude'].iloc[i] = df_codes['Latitude'].iloc[j]
      df['Longitude'].iloc[i] = df_codes['Longitude'].iloc[j]

# %%
df.head()
# Out:
#   Postcode           Borough                     Neighbourhood Latitude  \
# 0      M3A        North York                         Parkwoods  43.7533
# 1      M4A        North York                  Victoria Village  43.7259
# 2      M5A  Downtown Toronto         Regent Park, Harbourfront  43.6543
# 3      M6A        North York  Lawrence Manor, Lawrence Heights  43.7185
# 4      M7A      Queen's Park                      Queen's Park  43.6623
#
#   Longitude
# 0  -79.3297
# 1  -79.3156
# 2  -79.3606
# 3  -79.4648
# 4  -79.3895

# %% [markdown]
# **Part 3**

# %% [markdown]
# As per the instructions, we need to reduce the dataset just to Toronto postcodes.

# %%
from geopy.geocoders import Nominatim
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
import folium
import requests
import json
from pandas.io.json import json_normalize

# %%
x, y = df.shape
df_toronto = pd.DataFrame(columns=['Postcode', 'Borough', 'Neighbourhood', 'Latitude', 'Longitude'])
for i in range(x):
  if 'oronto' in df['Borough'].iloc[i]:
    df_toronto = df_toronto.append(pd.DataFrame(df.iloc[i]).transpose())
df_toronto = df_toronto.reset_index()
del df_toronto['index']

# %%
df_toronto.head()
# Out:
#   Postcode           Borough              Neighbourhood Latitude Longitude
# 0      M5A  Downtown Toronto  Regent Park, Harbourfront  43.6543  -79.3606
# 1      M5B  Downtown Toronto   Garden District, Ryerson  43.6572  -79.3789
# 2      M5C  Downtown Toronto             St. James Town  43.6515  -79.3754
# 3      M4E      East Toronto                The Beaches  43.6764   -79.293
# 4      M5E  Downtown Toronto                Berczy Park  43.6448  -79.3733

# %%
df_toronto.shape
# Out:
# (38, 5)

# %%
address = 'Toronto, ON'

geolocator = Nominatim(user_agent="toronto_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude

map_toronto = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, borough, neighbourhood in zip(df_toronto['Latitude'], df_toronto['Longitude'], df_toronto['Borough'], df_toronto['Neighbourhood']):
    label = '{}, {}'.format(neighbourhood, borough)
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_toronto)  
    
map_toronto
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# Use Foursquare to explore the area.

# %%
CLIENT_ID = 'AVHIEHE2J0LUDCC31OZKIIWWYNLJX1121GRVWSD4CBNLLXJJ' # your Foursquare ID
CLIENT_SECRET = 'VUJLZH2IPM5KACCSBU4CXE3O3I1GGVGLSVBIUWY0GQAMHTMU' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version

# %% [markdown]
# Function to pull the nearby venues from one or more given neighbourhoods. Use it to generate a dataframe of venues.

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):
    
    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
        print(name)
            
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return relevant information
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighbourhood', 
                  'Neighbourhood Latitude', 
                  'Neighbourhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %%
LIMIT = 100
toronto_venues = getNearbyVenues(names=df_toronto['Neighbourhood'],
                                   latitudes=df_toronto['Latitude'],
                                   longitudes=df_toronto['Longitude']
                                  )
# Out:
# Regent Park, Harbourfront
# Garden District, Ryerson
# St. James Town
# The Beaches
# Berczy Park
# Central Bay Street
# Christie
# Richmond, Adelaide, King, Adelaide
# Dufferin, Dovercourt Village
# Union Station, Harbourfront East, Toronto Islands, Harbourfront East
# Trinity, Little Portugal
# Riverdale, The Danforth West
# Toronto Dominion Centre, Design Exchange
# Parkdale Village, Brockton, Exhibition Place, Brockton
# India Bazaar, The Beaches West
# Victoria Hotel, Commerce Court
# Studio District
# Lawrence Park
# Roselawn
# Davisville North
# Forest Hill West, Forest Hill North
# The Junction South, High Park
# North Toronto West
# Yorkville, The Annex, North Midtown, The Annex
# Roncesvalles, Parkdale
# Davisville
# University of Toronto, Harbord
# Swansea, Runnymede
# Summerhill East, Moore Park
# Kensington Market, Chinatown, Grange Park, Chinatown
# Summerhill West, Deer Park, Forest Hill SE, Deer Park, Rathnelly, Deer Park, Forest Hill SE, Deer Park, South Hill, Deer Park, Forest Hill SE, Deer Park, Rathnelly, Deer Park, Forest Hill SE, Deer Park
# South Niagara, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Harbourfront West, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, King and Spadina, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Harbourfront West, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Railway Lands, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Harbourfront West, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, King and Spadina, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Harbourfront West, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower
# Rosedale
# Stn A PO Boxes 25 The Esplanade
# St. James Town, Cabbagetown
# Underground city, First Canadian Place
# Church and Wellesley
# Business Reply Mail Processing Centre 969 Eastern

# %%
print(toronto_venues.shape)
toronto_venues.head()
# Out:
# (1705, 7)
#                Neighbourhood  Neighbourhood Latitude  Neighbourhood Longitude  \
# 0  Regent Park, Harbourfront                43.65426               -79.360636
# 1  Regent Park, Harbourfront                43.65426               -79.360636
# 2  Regent Park, Harbourfront                43.65426               -79.360636
# 3  Regent Park, Harbourfront                43.65426               -79.360636
# 4  Regent Park, Harbourfront                43.65426               -79.360636
#
#                                              Venue  Venue Latitude  \
# 0                                 Roselle Desserts       43.653447
# 1                                    Tandem Coffee       43.653559
# 2  Toronto Cooper Koo Family Cherry St YMCA Centre       43.653191
# 3                              Body Blitz Spa East       43.654735
# 4                               Morning Glory Cafe       43.653947
#
#    Venue Longitude        Venue Category
# 0       -79.362017                Bakery
# 1       -79.361809           Coffee Shop
# 2       -79.357947  Gym / Fitness Center
# 3       -79.359874                   Spa
# 4       -79.361149        Breakfast Spot

# %%
toronto_venues.groupby('Neighbourhood').count()
# Out:
#                                                     Neighbourhood Latitude  \
# Neighbourhood
# Berczy Park                                                             56
# Business Reply Mail Processing Centre 969 Eastern                       16
# Central Bay Street                                                      81
# Christie                                                                17
# Church and Wellesley                                                    90
# Davisville                                                              34
# Davisville North                                                         7
# Dufferin, Dovercourt Village                                            15
# Forest Hill West, Forest Hill North                                      4
# Garden District, Ryerson                                               100
# India Bazaar, The Beaches West                                          20
# Kensington Market, Chinatown, Grange Park, Chin...                      98
# Lawrence Park                                                            4
# North Toronto West                                                      21
# Parkdale Village, Brockton, Exhibition Place, B...                      22
# Regent Park, Harbourfront                                               52
# Richmond, Adelaide, King, Adelaide                                     100
# Riverdale, The Danforth West                                            42
# Roncesvalles, Parkdale                                                  15
# Rosedale                                                                 4
# Roselawn                                                                 2
# South Niagara, CN Tower, Bathurst Quay, CN Towe...                      16
# St. James Town                                                         100
# St. James Town, Cabbagetown                                             45
# Stn A PO Boxes 25 The Esplanade                                         98
# Studio District                                                         40
# Summerhill East, Moore Park                                              4
# Summerhill West, Deer Park, Forest Hill SE, Dee...                      15
# Swansea, Runnymede                                                      36
# The Beaches                                                              4
# The Junction South, High Park                                           24
# Toronto Dominion Centre, Design Exchange                               100
# Trinity, Little Portugal                                                65
# Underground city, First Canadian Place                                 100
# Union Station, Harbourfront East, Toronto Islan...                     100
# University of Toronto, Harbord                                          37
# Victoria Hotel, Commerce Court                                         100
# Yorkville, The Annex, North Midtown, The Annex                          21
#
#                                                     Neighbourhood Longitude  \
# Neighbourhood
# Berczy Park                                                              56
# Business Reply Mail Processing Centre 969 Eastern                        16
# Central Bay Street                                                       81
# Christie                                                                 17
# Church and Wellesley                                                     90
# Davisville                                                               34
# Davisville North                                                          7
# Dufferin, Dovercourt Village                                             15
# Forest Hill West, Forest Hill North                                       4
# Garden District, Ryerson                                                100
# India Bazaar, The Beaches West                                           20
# Kensington Market, Chinatown, Grange Park, Chin...                       98
# Lawrence Park                                                             4
# North Toronto West                                                       21
# Parkdale Village, Brockton, Exhibition Place, B...                       22
# Regent Park, Harbourfront                                                52
# Richmond, Adelaide, King, Adelaide                                      100
# Riverdale, The Danforth West                                             42
# Roncesvalles, Parkdale                                                   15
# Rosedale                                                                  4
# Roselawn                                                                  2
# South Niagara, CN Tower, Bathurst Quay, CN Towe...                       16
# St. James Town                                                          100
# St. James Town, Cabbagetown                                              45
# Stn A PO Boxes 25 The Esplanade                                          98
# Studio District                                                          40
# Summerhill East, Moore Park                                               4
# Summerhill West, Deer Park, Forest Hill SE, Dee...                       15
# Swansea, Runnymede                                                       36
# The Beaches                                                               4
# The Junction South, High Park                                            24
# Toronto Dominion Centre, Design Exchange                                100
# Trinity, Little Portugal                                                 65
# Underground city, First Canadian Place                                  100
# Union Station, Harbourfront East, Toronto Islan...                      100
# University of Toronto, Harbord                                           37
# Victoria Hotel, Commerce Court                                          100
# Yorkville, The Annex, North Midtown, The Annex                           21
#
#                                                     Venue  Venue Latitude  \
# Neighbourhood
# Berczy Park                                            56              56
# Business Reply Mail Processing Centre 969 Eastern      16              16
# Central Bay Street                                     81              81
# Christie                                               17              17
# Church and Wellesley                                   90              90
# Davisville                                             34              34
# Davisville North                                        7               7
# Dufferin, Dovercourt Village                           15              15
# Forest Hill West, Forest Hill North                     4               4
# Garden District, Ryerson                              100             100
# India Bazaar, The Beaches West                         20              20
# Kensington Market, Chinatown, Grange Park, Chin...     98              98
# Lawrence Park                                           4               4
# North Toronto West                                     21              21
# Parkdale Village, Brockton, Exhibition Place, B...     22              22
# Regent Park, Harbourfront                              52              52
# Richmond, Adelaide, King, Adelaide                    100             100
# Riverdale, The Danforth West                           42              42
# Roncesvalles, Parkdale                                 15              15
# Rosedale                                                4               4
# Roselawn                                                2               2
# South Niagara, CN Tower, Bathurst Quay, CN Towe...     16              16
# St. James Town                                        100             100
# St. James Town, Cabbagetown                            45              45
# Stn A PO Boxes 25 The Esplanade                        98              98
# Studio District                                        40              40
# Summerhill East, Moore Park                             4               4
# Summerhill West, Deer Park, Forest Hill SE, Dee...     15              15
# Swansea, Runnymede                                     36              36
# The Beaches                                             4               4
# The Junction South, High Park                          24              24
# Toronto Dominion Centre, Design Exchange              100             100
# Trinity, Little Portugal                               65              65
# Underground city, First Canadian Place                100             100
# Union Station, Harbourfront East, Toronto Islan...    100             100
# University of Toronto, Harbord                         37              37
# Victoria Hotel, Commerce Court                        100             100
# Yorkville, The Annex, North Midtown, The Annex         21              21
#
#                                                     Venue Longitude  \
# Neighbourhood
# Berczy Park                                                      56
# Business Reply Mail Processing Centre 969 Eastern                16
# Central Bay Street                                               81
# Christie                                                         17
# Church and Wellesley                                             90
# Davisville                                                       34
# Davisville North                                                  7
# Dufferin, Dovercourt Village                                     15
# Forest Hill West, Forest Hill North                               4
# Garden District, Ryerson                                        100
# India Bazaar, The Beaches West                                   20
# Kensington Market, Chinatown, Grange Park, Chin...               98
# Lawrence Park                                                     4
# North Toronto West                                               21
# Parkdale Village, Brockton, Exhibition Place, B...               22
# Regent Park, Harbourfront                                        52
# Richmond, Adelaide, King, Adelaide                              100
# Riverdale, The Danforth West                                     42
# Roncesvalles, Parkdale                                           15
# Rosedale                                                          4
# Roselawn                                                          2
# South Niagara, CN Tower, Bathurst Quay, CN Towe...               16
# St. James Town                                                  100
# St. James Town, Cabbagetown                                      45
# Stn A PO Boxes 25 The Esplanade                                  98
# Studio District                                                  40
# Summerhill East, Moore Park                                       4
# Summerhill West, Deer Park, Forest Hill SE, Dee...               15
# Swansea, Runnymede                                               36
# The Beaches                                                       4
# The Junction South, High Park                                    24
# Toronto Dominion Centre, Design Exchange                        100
# Trinity, Little Portugal                                         65
# Underground city, First Canadian Place                          100
# Union Station, Harbourfront East, Toronto Islan...              100
# University of Toronto, Harbord                                   37
# Victoria Hotel, Commerce Court                                  100
# Yorkville, The Annex, North Midtown, The Annex                   21
#
#                                                     Venue Category
# Neighbourhood
# Berczy Park                                                     56
# Business Reply Mail Processing Centre 969 Eastern               16
# Central Bay Street                                              81
# Christie                                                        17
# Church and Wellesley                                            90
# Davisville                                                      34
# Davisville North                                                 7
# Dufferin, Dovercourt Village                                    15
# Forest Hill West, Forest Hill North                              4
# Garden District, Ryerson                                       100
# India Bazaar, The Beaches West                                  20
# Kensington Market, Chinatown, Grange Park, Chin...              98
# Lawrence Park                                                    4
# North Toronto West                                              21
# Parkdale Village, Brockton, Exhibition Place, B...              22
# Regent Park, Harbourfront                                       52
# Richmond, Adelaide, King, Adelaide                             100
# Riverdale, The Danforth West                                    42
# Roncesvalles, Parkdale                                          15
# Rosedale                                                         4
# Roselawn                                                         2
# South Niagara, CN Tower, Bathurst Quay, CN Towe...              16
# St. James Town                                                 100
# St. James Town, Cabbagetown                                     45
# Stn A PO Boxes 25 The Esplanade                                 98
# Studio District                                                 40
# Summerhill East, Moore Park                                      4
# Summerhill West, Deer Park, Forest Hill SE, Dee...              15
# Swansea, Runnymede                                              36
# The Beaches                                                      4
# The Junction South, High Park                                   24
# Toronto Dominion Centre, Design Exchange                       100
# Trinity, Little Portugal                                        65
# Underground city, First Canadian Place                         100
# Union Station, Harbourfront East, Toronto Islan...             100
# University of Toronto, Harbord                                  37
# Victoria Hotel, Commerce Court                                 100
# Yorkville, The Annex, North Midtown, The Annex                  21

# %%
print('There are {} uniques categories.'.format(len(toronto_venues['Venue Category'].unique())))
# Out:
# There are 234 uniques categories.

# %% [markdown]
# Analyze each neighbourhood.

# %%
toronto_onehot = pd.get_dummies(toronto_venues[['Venue Category']], prefix="", prefix_sep="")
toronto_onehot['Neighbourhood'] = toronto_venues['Neighbourhood'] 
fixed_columns = [toronto_onehot.columns[-1]] + list(toronto_onehot.columns[:-1])
toronto_onehot = toronto_onehot[fixed_columns]

toronto_grouped = toronto_onehot.groupby('Neighbourhood').mean().reset_index()
toronto_grouped
# Out:
#                                         Neighbourhood  Afghan Restaurant  \
# 0                                         Berczy Park           0.000000
# 1   Business Reply Mail Processing Centre 969 Eastern           0.000000
# 2                                  Central Bay Street           0.000000
# 3                                            Christie           0.000000
# 4                                Church and Wellesley           0.011111
# 5                                          Davisville           0.000000
# 6                                    Davisville North           0.000000
# 7                        Dufferin, Dovercourt Village           0.000000
# 8                 Forest Hill West, Forest Hill North           0.000000
# 9                            Garden District, Ryerson           0.000000
# 10                     India Bazaar, The Beaches West           0.000000
# 11  Kensington Market, Chinatown, Grange Park, Chi...           0.000000
# 12                                      Lawrence Park           0.000000
# 13                                 North Toronto West           0.000000
# 14  Parkdale Village, Brockton, Exhibition Place, ...           0.000000
# 15                          Regent Park, Harbourfront           0.000000
# 16                 Richmond, Adelaide, King, Adelaide           0.000000
# 17                       Riverdale, The Danforth West           0.000000
# 18                             Roncesvalles, Parkdale           0.000000
# 19                                           Rosedale           0.000000
# 20                                           Roselawn           0.000000
# 21  South Niagara, CN Tower, Bathurst Quay, CN Tow...           0.000000
# 22                                     St. James Town           0.000000
# 23                        St. James Town, Cabbagetown           0.000000
# 24                    Stn A PO Boxes 25 The Esplanade           0.000000
# 25                                    Studio District           0.000000
# 26                        Summerhill East, Moore Park           0.000000
# 27  Summerhill West, Deer Park, Forest Hill SE, De...           0.000000
# 28                                 Swansea, Runnymede           0.000000
# 29                                        The Beaches           0.000000
# 30                      The Junction South, High Park           0.000000
# 31           Toronto Dominion Centre, Design Exchange           0.000000
# 32                           Trinity, Little Portugal           0.000000
# 33             Underground city, First Canadian Place           0.000000
# 34  Union Station, Harbourfront East, Toronto Isla...           0.000000
# 35                     University of Toronto, Harbord           0.000000
# 36                     Victoria Hotel, Commerce Court           0.000000
# 37     Yorkville, The Annex, North Midtown, The Annex           0.000000
#
#     Airport  Airport Food Court  Airport Gate  Airport Lounge  \
# 0    0.0000              0.0000        0.0000           0.000
# 1    0.0000              0.0000        0.0000           0.000
# 2    0.0000              0.0000        0.0000           0.000
# 3    0.0000              0.0000        0.0000           0.000
# 4    0.0000              0.0000        0.0000           0.000
# 5    0.0000              0.0000        0.0000           0.000
# 6    0.0000              0.0000        0.0000           0.000
# 7    0.0000              0.0000        0.0000           0.000
# 8    0.0000              0.0000        0.0000           0.000
# 9    0.0000              0.0000        0.0000           0.000
# 10   0.0000              0.0000        0.0000           0.000
# 11   0.0000              0.0000        0.0000           0.000
# 12   0.0000              0.0000        0.0000           0.000
# 13   0.0000              0.0000        0.0000           0.000
# 14   0.0000              0.0000        0.0000           0.000
# 15   0.0000              0.0000        0.0000           0.000
# 16   0.0000              0.0000        0.0000           0.000
# 17   0.0000              0.0000        0.0000           0.000
# 18   0.0000              0.0000        0.0000           0.000
# 19   0.0000              0.0000        0.0000           0.000
# 20   0.0000              0.0000        0.0000           0.000
# 21   0.0625              0.0625        0.0625           0.125
# 22   0.0000              0.0000        0.0000           0.000
# 23   0.0000              0.0000        0.0000           0.000
# 24   0.0000              0.0000        0.0000           0.000
# 25   0.0000              0.0000        0.0000           0.000
# 26   0.0000              0.0000        0.0000           0.000
# 27   0.0000              0.0000        0.0000           0.000
# 28   0.0000              0.0000        0.0000           0.000
# 29   0.0000              0.0000        0.0000           0.000
# 30   0.0000              0.0000        0.0000           0.000
# 31   0.0000              0.0000        0.0000           0.000
# 32   0.0000              0.0000        0.0000           0.000
# 33   0.0000              0.0000        0.0000           0.000
# 34   0.0000              0.0000        0.0000           0.000
# 35   0.0000              0.0000        0.0000           0.000
# 36   0.0000              0.0000        0.0000           0.000
# 37   0.0000              0.0000        0.0000           0.000
#
#     Airport Service  Airport Terminal  American Restaurant  Antique Shop  ...  \
# 0            0.0000             0.000             0.000000      0.000000  ...
# 1            0.0000             0.000             0.000000      0.000000  ...
# 2            0.0000             0.000             0.012346      0.000000  ...
# 3            0.0000             0.000             0.000000      0.000000  ...
# 4            0.0000             0.000             0.011111      0.000000  ...
# 5            0.0000             0.000             0.000000      0.000000  ...
# 6            0.0000             0.000             0.000000      0.000000  ...
# 7            0.0000             0.000             0.000000      0.000000  ...
# 8            0.0000             0.000             0.000000      0.000000  ...
# 9            0.0000             0.000             0.010000      0.000000  ...
# 10           0.0000             0.000             0.000000      0.000000  ...
# 11           0.0000             0.000             0.000000      0.000000  ...
# 12           0.0000             0.000             0.000000      0.000000  ...
# 13           0.0000             0.000             0.000000      0.000000  ...
# 14           0.0000             0.000             0.000000      0.000000  ...
# 15           0.0000             0.000             0.000000      0.019231  ...
# 16           0.0000             0.000             0.030000      0.000000  ...
# 17           0.0000             0.000             0.023810      0.000000  ...
# 18           0.0000             0.000             0.000000      0.000000  ...
# 19           0.0000             0.000             0.000000      0.000000  ...
# 20           0.0000             0.000             0.000000      0.000000  ...
# 21           0.1875             0.125             0.000000      0.000000  ...
# 22           0.0000             0.000             0.020000      0.000000  ...
# 23           0.0000             0.000             0.000000      0.000000  ...
# 24           0.0000             0.000             0.010204      0.010204  ...
# 25           0.0000             0.000             0.050000      0.000000  ...
# 26           0.0000             0.000             0.000000      0.000000  ...
# 27           0.0000             0.000             0.066667      0.000000  ...
# 28           0.0000             0.000             0.000000      0.000000  ...
# 29           0.0000             0.000             0.000000      0.000000  ...
# 30           0.0000             0.000             0.000000      0.000000  ...
# 31           0.0000             0.000             0.040000      0.000000  ...
# 32           0.0000             0.000             0.000000      0.000000  ...
# 33           0.0000             0.000             0.030000      0.000000  ...
# 34           0.0000             0.000             0.000000      0.000000  ...
# 35           0.0000             0.000             0.000000      0.000000  ...
# 36           0.0000             0.000             0.040000      0.000000  ...
# 37           0.0000             0.000             0.047619      0.000000  ...
#
#     Toy / Game Store    Trail  Train Station  Vegetarian / Vegan Restaurant  \
# 0           0.000000  0.00000           0.00                       0.017857
# 1           0.000000  0.00000           0.00                       0.000000
# 2           0.000000  0.00000           0.00                       0.012346
# 3           0.000000  0.00000           0.00                       0.000000
# 4           0.000000  0.00000           0.00                       0.000000
# 5           0.029412  0.00000           0.00                       0.000000
# 6           0.000000  0.00000           0.00                       0.000000
# 7           0.000000  0.00000           0.00                       0.000000
# 8           0.000000  0.25000           0.00                       0.000000
# 9           0.010000  0.00000           0.00                       0.010000
# 10          0.000000  0.00000           0.00                       0.000000
# 11          0.010204  0.00000           0.00                       0.051020
# 12          0.000000  0.00000           0.00                       0.000000
# 13          0.000000  0.00000           0.00                       0.000000
# 14          0.000000  0.00000           0.00                       0.000000
# 15          0.000000  0.00000           0.00                       0.000000
# 16          0.000000  0.00000           0.00                       0.010000
# 17          0.000000  0.02381           0.00                       0.000000
# 18          0.000000  0.00000           0.00                       0.000000
# 19          0.000000  0.25000           0.00                       0.000000
# 20          0.000000  0.00000           0.00                       0.000000
# 21          0.000000  0.00000           0.00                       0.000000
# 22          0.000000  0.00000           0.00                       0.010000
# 23          0.000000  0.00000           0.00                       0.000000
# 24          0.000000  0.00000           0.00                       0.010204
# 25          0.000000  0.00000           0.00                       0.000000
# 26          0.000000  0.25000           0.00                       0.000000
# 27          0.000000  0.00000           0.00                       0.000000
# 28          0.000000  0.00000           0.00                       0.027778
# 29          0.000000  0.25000           0.00                       0.000000
# 30          0.000000  0.00000           0.00                       0.000000
# 31          0.000000  0.00000           0.01                       0.010000
# 32          0.000000  0.00000           0.00                       0.015385
# 33          0.000000  0.00000           0.01                       0.010000
# 34          0.000000  0.00000           0.01                       0.010000
# 35          0.000000  0.00000           0.00                       0.000000
# 36          0.000000  0.00000           0.00                       0.020000
# 37          0.000000  0.00000           0.00                       0.047619
#
#     Video Game Store  Vietnamese Restaurant  Wine Bar  Wings Joint  \
# 0           0.000000               0.000000  0.000000     0.000000
# 1           0.000000               0.000000  0.000000     0.000000
# 2           0.000000               0.000000  0.012346     0.000000
# 3           0.000000               0.000000  0.000000     0.000000
# 4           0.011111               0.011111  0.000000     0.011111
# 5           0.000000               0.000000  0.000000     0.000000
# 6           0.000000               0.000000  0.000000     0.000000
# 7           0.000000               0.000000  0.000000     0.000000
# 8           0.000000               0.000000  0.000000     0.000000
# 9           0.010000               0.010000  0.010000     0.000000
# 10          0.000000               0.000000  0.000000     0.000000
# 11          0.000000               0.061224  0.010204     0.000000
# 12          0.000000               0.000000  0.000000     0.000000
# 13          0.000000               0.000000  0.000000     0.000000
# 14          0.000000               0.000000  0.000000     0.000000
# 15          0.000000               0.000000  0.000000     0.000000
# 16          0.000000               0.000000  0.010000     0.000000
# 17          0.000000               0.000000  0.000000     0.000000
# 18          0.000000               0.000000  0.000000     0.000000
# 19          0.000000               0.000000  0.000000     0.000000
# 20          0.000000               0.000000  0.000000     0.000000
# 21          0.000000               0.000000  0.000000     0.000000
# 22          0.000000               0.000000  0.010000     0.000000
# 23          0.000000               0.000000  0.000000     0.000000
# 24          0.000000               0.000000  0.000000     0.000000
# 25          0.000000               0.000000  0.000000     0.000000
# 26          0.000000               0.000000  0.000000     0.000000
# 27          0.000000               0.066667  0.000000     0.000000
# 28          0.000000               0.000000  0.000000     0.000000
# 29          0.000000               0.000000  0.000000     0.000000
# 30          0.000000               0.000000  0.000000     0.000000
# 31          0.000000               0.000000  0.010000     0.000000
# 32          0.000000               0.030769  0.015385     0.000000
# 33          0.000000               0.000000  0.010000     0.000000
# 34          0.000000               0.000000  0.010000     0.000000
# 35          0.027027               0.000000  0.000000     0.000000
# 36          0.000000               0.000000  0.010000     0.000000
# 37          0.000000               0.000000  0.000000     0.000000
#
#     Women's Store  Yoga Studio
# 0            0.00     0.000000
# 1            0.00     0.062500
# 2            0.00     0.012346
# 3            0.00     0.000000
# 4            0.00     0.011111
# 5            0.00     0.000000
# 6            0.00     0.000000
# 7            0.00     0.000000
# 8            0.00     0.000000
# 9            0.00     0.000000
# 10           0.00     0.000000
# 11           0.00     0.000000
# 12           0.00     0.000000
# 13           0.00     0.047619
# 14           0.00     0.000000
# 15           0.00     0.019231
# 16           0.01     0.000000
# 17           0.00     0.023810
# 18           0.00     0.000000
# 19           0.00     0.000000
# 20           0.00     0.000000
# 21           0.00     0.000000
# 22           0.00     0.000000
# 23           0.00     0.000000
# 24           0.00     0.000000
# 25           0.00     0.025000
# 26           0.00     0.000000
# 27           0.00     0.000000
# 28           0.00     0.000000
# 29           0.00     0.000000
# 30           0.00     0.000000
# 31           0.00     0.000000
# 32           0.00     0.015385
# 33           0.00     0.000000
# 34           0.00     0.000000
# 35           0.00     0.027027
# 36           0.00     0.000000
# 37           0.00     0.000000
#
# [38 rows x 235 columns]

# %%
num_top_venues = 5

for hood in toronto_grouped['Neighbourhood']:
    print("----"+hood+"----")
    temp = toronto_grouped[toronto_grouped['Neighbourhood'] == hood].T.reset_index()
    temp.columns = ['venue','freq']
    temp = temp.iloc[1:]
    temp['freq'] = temp['freq'].astype(float)
    temp = temp.round({'freq': 2})
    print(temp.sort_values('freq', ascending=False).reset_index(drop=True).head(num_top_venues))
    print('\n')
# Out:
# ----Berczy Park----
#                 venue  freq
# 0         Coffee Shop  0.07
# 1  Italian Restaurant  0.04
# 2      Farmers Market  0.04
# 3                Café  0.04
# 4         Cheese Shop  0.04
#
#
# ----Business Reply Mail Processing Centre 969 Eastern----
#                 venue  freq
# 0         Yoga Studio  0.06
# 1       Auto Workshop  0.06
# 2       Garden Center  0.06
# 3              Garden  0.06
# 4  Light Rail Station  0.06
#
#
# ----Central Bay Street----
#                 venue  freq
# 0         Coffee Shop  0.14
# 1                Café  0.05
# 2      Ice Cream Shop  0.05
# 3  Italian Restaurant  0.05
# 4        Burger Joint  0.04
#
#
# ----Christie----
#                venue  freq
# 0               Café  0.18
# 1      Grocery Store  0.18
# 2               Park  0.12
# 3         Baby Store  0.06
# 4  Convenience Store  0.06
#
#
# ----Church and Wellesley----
#                  venue  freq
# 0          Coffee Shop  0.08
# 1  Japanese Restaurant  0.06
# 2     Sushi Restaurant  0.04
# 3           Restaurant  0.03
# 4              Gay Bar  0.03
#
#
# ----Davisville----
#                 venue  freq
# 0      Sandwich Place  0.09
# 1        Dessert Shop  0.09
# 2    Sushi Restaurant  0.06
# 3         Coffee Shop  0.06
# 4  Italian Restaurant  0.06
#
#
# ----Davisville North----
#                venue  freq
# 0     Sandwich Place  0.14
# 1                Gym  0.14
# 2     Clothing Store  0.14
# 3  Food & Drink Shop  0.14
# 4               Park  0.14
#
#
# ----Dufferin, Dovercourt Village----
#          venue  freq
# 0       Bakery  0.13
# 1     Pharmacy  0.13
# 2  Supermarket  0.13
# 3      Brewery  0.07
# 4          Bar  0.07
#
#
# ----Forest Hill West, Forest Hill North----
#                 venue  freq
# 0  Mexican Restaurant  0.25
# 1    Sushi Restaurant  0.25
# 2               Trail  0.25
# 3       Jewelry Store  0.25
# 4   Afghan Restaurant  0.00
#
#
# ----Garden District, Ryerson----
#             venue  freq
# 0  Clothing Store  0.08
# 1     Coffee Shop  0.07
# 2  Cosmetics Shop  0.04
# 3          Bakery  0.03
# 4            Café  0.03
#
#
# ----India Bazaar, The Beaches West----
#                venue  freq
# 0        Pizza Place  0.10
# 1     Sandwich Place  0.10
# 2  Fish & Chips Shop  0.05
# 3  Food & Drink Shop  0.05
# 4       Liquor Store  0.05
#
#
# ----Kensington Market, Chinatown, Grange Park, Chinatown----
#                            venue  freq
# 0          Vietnamese Restaurant  0.06
# 1                            Bar  0.06
# 2                           Café  0.05
# 3             Chinese Restaurant  0.05
# 4  Vegetarian / Vegan Restaurant  0.05
#
#
# ----Lawrence Park----
#                 venue  freq
# 0                Park  0.25
# 1         Swim School  0.25
# 2            Bus Line  0.25
# 3  Dim Sum Restaurant  0.25
# 4   Afghan Restaurant  0.00
#
#
# ----North Toronto West----
#                  venue  freq
# 0       Clothing Store  0.10
# 1          Coffee Shop  0.10
# 2  Sporting Goods Shop  0.10
# 3          Yoga Studio  0.05
# 4  Rental Car Location  0.05
#
#
# ----Parkdale Village, Brockton, Exhibition Place, Brockton----
#             venue  freq
# 0  Breakfast Spot  0.09
# 1            Café  0.09
# 2     Coffee Shop  0.09
# 3          Bakery  0.05
# 4      Restaurant  0.05
#
#
# ----Regent Park, Harbourfront----
#          venue  freq
# 0  Coffee Shop  0.17
# 1         Park  0.08
# 2         Café  0.06
# 3          Pub  0.06
# 4       Bakery  0.06
#
#
# ----Richmond, Adelaide, King, Adelaide----
#              venue  freq
# 0      Coffee Shop  0.07
# 1             Café  0.05
# 2              Bar  0.04
# 3  Thai Restaurant  0.04
# 4            Hotel  0.03
#
#
# ----Riverdale, The Danforth West----
#                     venue  freq
# 0        Greek Restaurant  0.19
# 1             Coffee Shop  0.10
# 2          Ice Cream Shop  0.07
# 3      Italian Restaurant  0.07
# 4  Furniture / Home Store  0.05
#
#
# ----Roncesvalles, Parkdale----
#                          venue  freq
# 0                  Coffee Shop  0.13
# 1                    Gift Shop  0.13
# 2                   Restaurant  0.07
# 3                         Bank  0.07
# 4  Eastern European Restaurant  0.07
#
#
# ----Rosedale----
#                venue  freq
# 0               Park  0.50
# 1         Playground  0.25
# 2              Trail  0.25
# 3  Afghan Restaurant  0.00
# 4       Neighborhood  0.00
#
#
# ----Roselawn----
#                      venue  freq
# 0  Health & Beauty Service   0.5
# 1                   Garden   0.5
# 2        Afghan Restaurant   0.0
# 3  New American Restaurant   0.0
# 4              Men's Store   0.0
#
#
# ----South Niagara, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Harbourfront West, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, King and Spadina, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Harbourfront West, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Railway Lands, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Harbourfront West, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, King and Spadina, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower, Harbourfront West, CN Tower, Bathurst Quay, CN Tower, Island airport, CN Tower, Bathurst Quay, CN Tower----
#                 venue  freq
# 0     Airport Service  0.19
# 1      Airport Lounge  0.12
# 2    Airport Terminal  0.12
# 3         Coffee Shop  0.06
# 4  Airport Food Court  0.06
#
#
# ----St. James Town----
#             venue  freq
# 0     Coffee Shop  0.07
# 1      Restaurant  0.05
# 2            Café  0.05
# 3           Hotel  0.05
# 4  Clothing Store  0.04
#
#
# ----St. James Town, Cabbagetown----
#          venue  freq
# 0  Coffee Shop  0.07
# 1   Restaurant  0.07
# 2       Bakery  0.04
# 3  Pizza Place  0.04
# 4       Market  0.04
#
#
# ----Stn A PO Boxes 25 The Esplanade----
#                 venue  freq
# 0         Coffee Shop  0.11
# 1          Restaurant  0.04
# 2  Italian Restaurant  0.04
# 3                Café  0.04
# 4            Beer Bar  0.03
#
#
# ----Studio District----
#                  venue  freq
# 0                 Café  0.10
# 1          Coffee Shop  0.08
# 2   Italian Restaurant  0.05
# 3  American Restaurant  0.05
# 4               Bakery  0.05
#
#
# ----Summerhill East, Moore Park----
#           venue  freq
# 0    Playground  0.25
# 1          Park  0.25
# 2         Trail  0.25
# 3  Tennis Court  0.25
# 4     Pet Store  0.00
#
#
# ----Summerhill West, Deer Park, Forest Hill SE, Deer Park, Rathnelly, Deer Park, Forest Hill SE, Deer Park, South Hill, Deer Park, Forest Hill SE, Deer Park, Rathnelly, Deer Park, Forest Hill SE, Deer Park----
#           venue  freq
# 0           Pub  0.13
# 1   Coffee Shop  0.13
# 2    Bagel Shop  0.07
# 3    Restaurant  0.07
# 4  Liquor Store  0.07
#
#
# ----Swansea, Runnymede----
#                 venue  freq
# 0         Coffee Shop  0.08
# 1                Café  0.08
# 2         Pizza Place  0.06
# 3  Italian Restaurant  0.06
# 4    Sushi Restaurant  0.06
#
#
# ----The Beaches----
#                      venue  freq
# 0        Health Food Store  0.25
# 1                      Pub  0.25
# 2                    Trail  0.25
# 3             Neighborhood  0.25
# 4  New American Restaurant  0.00
#
#
# ----The Junction South, High Park----
#                 venue  freq
# 0                 Bar  0.08
# 1  Mexican Restaurant  0.08
# 2                Café  0.08
# 3     Thai Restaurant  0.08
# 4              Bakery  0.04
#
#
# ----Toronto Dominion Centre, Design Exchange----
#                  venue  freq
# 0          Coffee Shop  0.15
# 1                 Café  0.08
# 2                Hotel  0.06
# 3           Restaurant  0.05
# 4  American Restaurant  0.04
#
#
# ----Trinity, Little Portugal----
#               venue  freq
# 0               Bar  0.11
# 1       Coffee Shop  0.06
# 2  Asian Restaurant  0.05
# 3       Men's Store  0.05
# 4        Restaurant  0.05
#
#
# ----Underground city, First Canadian Place----
#          venue  freq
# 0  Coffee Shop  0.12
# 1         Café  0.07
# 2   Restaurant  0.04
# 3   Steakhouse  0.04
# 4        Hotel  0.04
#
#
# ----Union Station, Harbourfront East, Toronto Islands, Harbourfront East----
#                  venue  freq
# 0          Coffee Shop  0.13
# 1             Aquarium  0.05
# 2                Hotel  0.05
# 3                 Café  0.04
# 4  Fried Chicken Joint  0.03
#
#
# ----University of Toronto, Harbord----
#                  venue  freq
# 0                 Café  0.16
# 1           Restaurant  0.05
# 2   Italian Restaurant  0.05
# 3  Japanese Restaurant  0.05
# 4                  Bar  0.05
#
#
# ----Victoria Hotel, Commerce Court----
#                  venue  freq
# 0          Coffee Shop  0.12
# 1                 Café  0.07
# 2                Hotel  0.06
# 3           Restaurant  0.05
# 4  American Restaurant  0.04
#
#
# ----Yorkville, The Annex, North Midtown, The Annex----
#             venue  freq
# 0  Sandwich Place  0.14
# 1            Café  0.14
# 2     Coffee Shop  0.10
# 3  History Museum  0.05
# 4       BBQ Joint  0.05

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

num_top_venues = 10

indicators = ['st', 'nd', 'rd']

columns = ['Neighbourhood']
for i in np.arange(num_top_venues):
    try:
        columns.append('{}{} Most Common Venue'.format(i+1, indicators[i]))
    except:
        columns.append('{}th Most Common Venue'.format(i+1))

neighborhoods_venues_sorted = pd.DataFrame(columns=columns)
neighborhoods_venues_sorted['Neighbourhood'] = toronto_grouped['Neighbourhood']

for i in np.arange(toronto_grouped.shape[0]):
    neighborhoods_venues_sorted.iloc[i, 1:] = return_most_common_venues(toronto_grouped.iloc[i, :], num_top_venues)

neighborhoods_venues_sorted.head()
# Out:
#                                        Neighbourhood 1st Most Common Venue  \
# 0                                        Berczy Park           Coffee Shop
# 1  Business Reply Mail Processing Centre 969 Eastern           Yoga Studio
# 2                                 Central Bay Street           Coffee Shop
# 3                                           Christie         Grocery Store
# 4                               Church and Wellesley           Coffee Shop
#
#   2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 0          Cocktail Bar        Farmers Market              Beer Bar
# 1         Auto Workshop           Pizza Place            Comic Shop
# 2        Ice Cream Shop                  Café    Italian Restaurant
# 3                  Café                  Park     Convenience Store
# 4   Japanese Restaurant      Sushi Restaurant               Gay Bar
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0            Steakhouse                Bakery    Seafood Restaurant
# 1      Recording Studio            Restaurant         Burrito Place
# 2          Burger Joint        Sandwich Place       Bubble Tea Shop
# 3                 Diner           Candy Store            Baby Store
# 4          Burger Joint            Restaurant      Ramen Restaurant
#
#   8th Most Common Venue 9th Most Common Venue 10th Most Common Venue
# 0    Italian Restaurant           Cheese Shop                   Café
# 1            Skate Park               Brewery                    Spa
# 2  Gym / Fitness Center                Bakery     Chinese Restaurant
# 3    Athletics & Sports            Restaurant              Nightclub
# 4                   Gym             Gastropub                  Hotel

# %% [markdown]
# Now we cluster the neighborhoods by k-means.

# %%
kclusters = 5
toronto_grouped_clustering = toronto_grouped.drop('Neighbourhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(toronto_grouped_clustering)
kmeans.labels_[0:10] 
neighborhoods_venues_sorted.insert(0, 'Cluster Labels', kmeans.labels_)
toronto_merged = df_toronto
toronto_merged = toronto_merged.join(neighborhoods_venues_sorted.set_index('Neighbourhood'), on='Neighbourhood')

toronto_merged.head()
# Out:
#   Postcode           Borough              Neighbourhood Latitude Longitude  \
# 0      M5A  Downtown Toronto  Regent Park, Harbourfront  43.6543  -79.3606
# 1      M5B  Downtown Toronto   Garden District, Ryerson  43.6572  -79.3789
# 2      M5C  Downtown Toronto             St. James Town  43.6515  -79.3754
# 3      M4E      East Toronto                The Beaches  43.6764   -79.293
# 4      M5E  Downtown Toronto                Berczy Park  43.6448  -79.3733
#
#    Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 0               0           Coffee Shop                  Park
# 1               0        Clothing Store           Coffee Shop
# 2               0           Coffee Shop                  Café
# 3               0                 Trail     Health Food Store
# 4               0           Coffee Shop          Cocktail Bar
#
#   3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0                  Café                   Pub                Bakery
# 1        Cosmetics Shop                  Café                Bakery
# 2            Restaurant                 Hotel        Clothing Store
# 3                   Pub          Neighborhood           Event Space
# 4        Farmers Market              Beer Bar            Steakhouse
#
#   6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 0               Theater    Mexican Restaurant        Breakfast Spot
# 1  Fast Food Restaurant           Pizza Place       Bubble Tea Shop
# 2             Gastropub        Breakfast Spot        Cosmetics Shop
# 3  Ethiopian Restaurant    Falafel Restaurant     Electronics Store
# 4                Bakery    Seafood Restaurant    Italian Restaurant
#
#        9th Most Common Venue       10th Most Common Venue
# 0                Yoga Studio            French Restaurant
# 1  Middle Eastern Restaurant                   Restaurant
# 2         Italian Restaurant                       Bakery
# 3         Dim Sum Restaurant  Eastern European Restaurant
# 4                Cheese Shop                         Café

# %% [markdown]
# Lastly, let's visualize the clusters.

# %%
# create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(kclusters)
ys = [i + x + (i*x)**2 for i in range(kclusters)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(toronto_merged['Latitude'], toronto_merged['Longitude'], toronto_merged['Neighbourhood'], toronto_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
